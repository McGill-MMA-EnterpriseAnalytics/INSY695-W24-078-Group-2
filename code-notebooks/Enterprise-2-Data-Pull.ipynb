# %%
from pathlib import Path
import glob
import requests
import pandas as pd
import arrow

# %%
# Setting up API Base URL + Credentials

base_url: str = "https://api.aviationstack.com/v1/flights"

api_key: str = "*************************"

# %%
today = arrow.now()                             # grabbing today's date
start_date = today.shift(days = -90)            # date when to start the 90 day lookback window
offsets = [0, 100, 200]                         # working around the flightstack API response pagination

# %%
for i in range(91):

    dte = start_date.shift(days = i).format('YYYY-MM-DD')

    for offset in offsets:

        query_params: dict = {
            "access_key": api_key,
            "flight_date": dte,
            "limit": 100,
            "offset": offset,
            "dep_iata": "YUL",
        }

        response = requests.get(base_url, query_params)

        if response.status_code == 200:

            # print(f"Pull Successful - Writing to file # {i+1}...")

            response_json = response.json()

            required_data = response_json.get('data', [])

            structured_data: list = []

            for flight in required_data:

                if isinstance(flight, dict):

                    if flight['flight'].get('codeshared') is None:

                        structured_data.append({
                            'Flight Status': flight['flight_status'],
                            'Departure Airport': flight['departure'].get('iata', ''),
                            'Departure Gate': flight['departure'].get('gate', ''),
                            'Arrival IATA Code': flight['arrival'].get('iata', ''),
                            'Scheduled Departure': flight['departure'].get('scheduled', ''),
                            'Actual Departure': flight['departure'].get('actual', ''),
                            'Delay (in Minutes)': flight['departure'].get('delay', 0),
                            'Airline Name': flight['airline'].get('name', ''),
                            'Flight Number': flight['flight'].get('iata', ''),
                        })
                
            departures_df: pd.DataFrame = pd.DataFrame(structured_data)

            departures_df.to_csv(f"./flight_data/Enterprise-II-Data/YUL_Departures_{dte}_{offset}.csv", index = False)

            print("File written, onto the next one....")
# Out:
# Pull Successful - Writing to file # 1...
# File written, onto the next one....
# Pull Successful - Writing to file # 1...
# File written, onto the next one....
# Pull Successful - Writing to file # 1...
# File written, onto the next one....
# Pull Successful - Writing to file # 2...
# File written, onto the next one....
# Pull Successful - Writing to file # 2...
# File written, onto the next one....
# Pull Successful - Writing to file # 2...
# File written, onto the next one....
# Pull Successful - Writing to file # 3...
# File written, onto the next one....
# Pull Successful - Writing to file # 3...
# File written, onto the next one....
# Pull Successful - Writing to file # 3...
# File written, onto the next one....
# Pull Successful - Writing to file # 4...
# File written, onto the next one....
# Pull Successful - Writing to file # 5...
# File written, onto the next one....
# Pull Successful - Writing to file # 5...
# File written, onto the next one....
# Pull Successful - Writing to file # 5...
# File written, onto the next one....
# Pull Successful - Writing to file # 6...
# File written, onto the next one....
# Pull Successful - Writing to file # 6...
# File written, onto the next one....
# Pull Successful - Writing to file # 6...
# File written, onto the next one....
# Pull Successful - Writing to file # 7...
# File written, onto the next one....
# Pull Successful - Writing to file # 7...
# File written, onto the next one....
# Pull Successful - Writing to file # 7...
# File written, onto the next one....
# Pull Successful - Writing to file # 8...
# File written, onto the next one....
# Pull Successful - Writing to file # 8...
# File written, onto the next one....
# Pull Successful - Writing to file # 8...
# File written, onto the next one....
# Pull Successful - Writing to file # 9...
# File written, onto the next one....
# Pull Successful - Writing to file # 9...
# File written, onto the next one....
# Pull Successful - Writing to file # 9...
# File written, onto the next one....
# Pull Successful - Writing to file # 10...
# File written, onto the next one....
# Pull Successful - Writing to file # 10...
# File written, onto the next one....
# Pull Successful - Writing to file # 10...
# File written, onto the next one....
# Pull Successful - Writing to file # 11...
# File written, onto the next one....
# Pull Successful - Writing to file # 11...
# File written, onto the next one....
# Pull Successful - Writing to file # 11...
# File written, onto the next one....
# Pull Successful - Writing to file # 12...
# File written, onto the next one....
# Pull Successful - Writing to file # 12...
# File written, onto the next one....
# Pull Successful - Writing to file # 12...
# File written, onto the next one....
# Pull Successful - Writing to file # 13...
# File written, onto the next one....
# Pull Successful - Writing to file # 13...
# File written, onto the next one....
# Pull Successful - Writing to file # 13...
# File written, onto the next one....
# Pull Successful - Writing to file # 14...
# File written, onto the next one....
# Pull Successful - Writing to file # 14...
# File written, onto the next one....
# Pull Successful - Writing to file # 14...
# File written, onto the next one....
# Pull Successful - Writing to file # 15...
# File written, onto the next one....
# Pull Successful - Writing to file # 15...
# File written, onto the next one....
# Pull Successful - Writing to file # 15...
# File written, onto the next one....
# Pull Successful - Writing to file # 16...
# File written, onto the next one....
# Pull Successful - Writing to file # 16...
# File written, onto the next one....
# Pull Successful - Writing to file # 16...
# File written, onto the next one....
# Pull Successful - Writing to file # 17...
# File written, onto the next one....
# Pull Successful - Writing to file # 17...
# File written, onto the next one....
# Pull Successful - Writing to file # 17...
# File written, onto the next one....
# Pull Successful - Writing to file # 18...
# File written, onto the next one....
# Pull Successful - Writing to file # 18...
# File written, onto the next one....
# Pull Successful - Writing to file # 18...
# File written, onto the next one....
# Pull Successful - Writing to file # 19...
# File written, onto the next one....
# Pull Successful - Writing to file # 19...
# File written, onto the next one....
# Pull Successful - Writing to file # 19...
# File written, onto the next one....
# Pull Successful - Writing to file # 20...
# File written, onto the next one....
# Pull Successful - Writing to file # 20...
# File written, onto the next one....
# Pull Successful - Writing to file # 20...
# File written, onto the next one....
# Pull Successful - Writing to file # 21...
# File written, onto the next one....
# Pull Successful - Writing to file # 21...
# File written, onto the next one....
# Pull Successful - Writing to file # 21...
# File written, onto the next one....
# Pull Successful - Writing to file # 22...
# File written, onto the next one....
# Pull Successful - Writing to file # 22...
# File written, onto the next one....
# Pull Successful - Writing to file # 22...
# File written, onto the next one....
# Pull Successful - Writing to file # 23...
# File written, onto the next one....
# Pull Successful - Writing to file # 23...
# File written, onto the next one....
# Pull Successful - Writing to file # 23...
# File written, onto the next one....
# Pull Successful - Writing to file # 24...
# File written, onto the next one....
# Pull Successful - Writing to file # 24...
# File written, onto the next one....
# Pull Successful - Writing to file # 24...
# File written, onto the next one....
# Pull Successful - Writing to file # 25...
# File written, onto the next one....
# Pull Successful - Writing to file # 25...
# File written, onto the next one....
# Pull Successful - Writing to file # 25...
# File written, onto the next one....
# Pull Successful - Writing to file # 26...
# File written, onto the next one....
# Pull Successful - Writing to file # 26...
# File written, onto the next one....
# Pull Successful - Writing to file # 26...
# File written, onto the next one....
# Pull Successful - Writing to file # 27...
# File written, onto the next one....
# Pull Successful - Writing to file # 27...
# File written, onto the next one....
# Pull Successful - Writing to file # 27...
# File written, onto the next one....
# Pull Successful - Writing to file # 28...
# File written, onto the next one....
# Pull Successful - Writing to file # 28...
# File written, onto the next one....
# Pull Successful - Writing to file # 28...
# File written, onto the next one....
# Pull Successful - Writing to file # 29...
# File written, onto the next one....
# Pull Successful - Writing to file # 29...
# File written, onto the next one....
# Pull Successful - Writing to file # 29...
# File written, onto the next one....
# Pull Successful - Writing to file # 30...
# File written, onto the next one....
# Pull Successful - Writing to file # 30...
# File written, onto the next one....
# Pull Successful - Writing to file # 30...
# File written, onto the next one....
# Pull Successful - Writing to file # 31...
# File written, onto the next one....
# Pull Successful - Writing to file # 31...
# File written, onto the next one....
# Pull Successful - Writing to file # 31...
# File written, onto the next one....
# Pull Successful - Writing to file # 32...
# File written, onto the next one....
# Pull Successful - Writing to file # 32...
# File written, onto the next one....
# Pull Successful - Writing to file # 32...
# File written, onto the next one....
# Pull Successful - Writing to file # 33...
# File written, onto the next one....
# Pull Successful - Writing to file # 33...
# File written, onto the next one....
# Pull Successful - Writing to file # 33...
# File written, onto the next one....
# Pull Successful - Writing to file # 34...
# File written, onto the next one....
# Pull Successful - Writing to file # 34...
# File written, onto the next one....
# Pull Successful - Writing to file # 34...
# File written, onto the next one....
# Pull Successful - Writing to file # 35...
# File written, onto the next one....
# Pull Successful - Writing to file # 35...
# File written, onto the next one....
# Pull Successful - Writing to file # 35...
# File written, onto the next one....
# Pull Successful - Writing to file # 36...
# File written, onto the next one....
# Pull Successful - Writing to file # 36...
# File written, onto the next one....
# Pull Successful - Writing to file # 36...
# File written, onto the next one....
# Pull Successful - Writing to file # 37...
# File written, onto the next one....
# Pull Successful - Writing to file # 37...
# File written, onto the next one....
# Pull Successful - Writing to file # 37...
# File written, onto the next one....
# Pull Successful - Writing to file # 38...
# File written, onto the next one....
# Pull Successful - Writing to file # 38...
# File written, onto the next one....
# Pull Successful - Writing to file # 38...
# File written, onto the next one....
# Pull Successful - Writing to file # 39...
# File written, onto the next one....
# Pull Successful - Writing to file # 39...
# File written, onto the next one....
# Pull Successful - Writing to file # 39...
# File written, onto the next one....
# Pull Successful - Writing to file # 40...
# File written, onto the next one....
# Pull Successful - Writing to file # 40...
# File written, onto the next one....
# Pull Successful - Writing to file # 40...
# File written, onto the next one....
# Pull Successful - Writing to file # 41...
# File written, onto the next one....
# Pull Successful - Writing to file # 41...
# File written, onto the next one....
# Pull Successful - Writing to file # 41...
# File written, onto the next one....
# Pull Successful - Writing to file # 42...
# File written, onto the next one....
# Pull Successful - Writing to file # 42...
# File written, onto the next one....
# Pull Successful - Writing to file # 42...
# File written, onto the next one....
# Pull Successful - Writing to file # 43...
# File written, onto the next one....
# Pull Successful - Writing to file # 43...
# File written, onto the next one....
# Pull Successful - Writing to file # 43...
# File written, onto the next one....
# Pull Successful - Writing to file # 44...
# File written, onto the next one....
# Pull Successful - Writing to file # 44...
# File written, onto the next one....
# Pull Successful - Writing to file # 44...
# File written, onto the next one....
# Pull Successful - Writing to file # 45...
# File written, onto the next one....
# Pull Successful - Writing to file # 45...
# File written, onto the next one....
# Pull Successful - Writing to file # 45...
# File written, onto the next one....
# Pull Successful - Writing to file # 46...
# File written, onto the next one....
# Pull Successful - Writing to file # 46...
# File written, onto the next one....
# Pull Successful - Writing to file # 46...
# File written, onto the next one....
# Pull Successful - Writing to file # 47...
# File written, onto the next one....
# Pull Successful - Writing to file # 47...
# File written, onto the next one....
# Pull Successful - Writing to file # 47...
# File written, onto the next one....
# Pull Successful - Writing to file # 48...
# File written, onto the next one....
# Pull Successful - Writing to file # 48...
# File written, onto the next one....
# Pull Successful - Writing to file # 48...
# File written, onto the next one....
# Pull Successful - Writing to file # 49...
# File written, onto the next one....
# Pull Successful - Writing to file # 49...
# File written, onto the next one....
# Pull Successful - Writing to file # 49...
# File written, onto the next one....
# Pull Successful - Writing to file # 50...
# File written, onto the next one....
# Pull Successful - Writing to file # 50...
# File written, onto the next one....
# Pull Successful - Writing to file # 50...
# File written, onto the next one....
# Pull Successful - Writing to file # 51...
# File written, onto the next one....
# Pull Successful - Writing to file # 51...
# File written, onto the next one....
# Pull Successful - Writing to file # 51...
# File written, onto the next one....
# Pull Successful - Writing to file # 52...
# File written, onto the next one....
# Pull Successful - Writing to file # 52...
# File written, onto the next one....
# Pull Successful - Writing to file # 52...
# File written, onto the next one....
# Pull Successful - Writing to file # 53...
# File written, onto the next one....
# Pull Successful - Writing to file # 53...
# File written, onto the next one....
# Pull Successful - Writing to file # 53...
# File written, onto the next one....
# Pull Successful - Writing to file # 54...
# File written, onto the next one....
# Pull Successful - Writing to file # 54...
# File written, onto the next one....
# Pull Successful - Writing to file # 54...
# File written, onto the next one....
# Pull Successful - Writing to file # 55...
# File written, onto the next one....
# Pull Successful - Writing to file # 55...
# File written, onto the next one....
# Pull Successful - Writing to file # 55...
# File written, onto the next one....
# Pull Successful - Writing to file # 56...
# File written, onto the next one....
# Pull Successful - Writing to file # 56...
# File written, onto the next one....
# Pull Successful - Writing to file # 56...
# File written, onto the next one....
# Pull Successful - Writing to file # 57...
# File written, onto the next one....
# Pull Successful - Writing to file # 57...
# File written, onto the next one....
# Pull Successful - Writing to file # 57...
# File written, onto the next one....
# Pull Successful - Writing to file # 58...
# File written, onto the next one....
# Pull Successful - Writing to file # 58...
# File written, onto the next one....
# Pull Successful - Writing to file # 58...
# File written, onto the next one....
# Pull Successful - Writing to file # 59...
# File written, onto the next one....
# Pull Successful - Writing to file # 59...
# File written, onto the next one....
# Pull Successful - Writing to file # 59...
# File written, onto the next one....
# Pull Successful - Writing to file # 60...
# File written, onto the next one....
# Pull Successful - Writing to file # 60...
# File written, onto the next one....
# Pull Successful - Writing to file # 60...
# File written, onto the next one....
# Pull Successful - Writing to file # 61...
# File written, onto the next one....
# Pull Successful - Writing to file # 61...
# File written, onto the next one....
# Pull Successful - Writing to file # 61...
# File written, onto the next one....
# Pull Successful - Writing to file # 62...
# File written, onto the next one....
# Pull Successful - Writing to file # 62...
# File written, onto the next one....
# Pull Successful - Writing to file # 62...
# File written, onto the next one....
# Pull Successful - Writing to file # 63...
# File written, onto the next one....
# Pull Successful - Writing to file # 63...
# File written, onto the next one....
# Pull Successful - Writing to file # 63...
# File written, onto the next one....
# Pull Successful - Writing to file # 64...
# File written, onto the next one....
# Pull Successful - Writing to file # 64...
# File written, onto the next one....
# Pull Successful - Writing to file # 64...
# File written, onto the next one....
# Pull Successful - Writing to file # 65...
# File written, onto the next one....
# Pull Successful - Writing to file # 65...
# File written, onto the next one....
# Pull Successful - Writing to file # 65...
# File written, onto the next one....
# Pull Successful - Writing to file # 66...
# File written, onto the next one....
# Pull Successful - Writing to file # 66...
# File written, onto the next one....
# Pull Successful - Writing to file # 66...
# File written, onto the next one....
# Pull Successful - Writing to file # 67...
# File written, onto the next one....
# Pull Successful - Writing to file # 67...
# File written, onto the next one....
# Pull Successful - Writing to file # 67...
# File written, onto the next one....
# Pull Successful - Writing to file # 68...
# File written, onto the next one....
# Pull Successful - Writing to file # 68...
# File written, onto the next one....
# Pull Successful - Writing to file # 68...
# File written, onto the next one....
# Pull Successful - Writing to file # 69...
# File written, onto the next one....
# Pull Successful - Writing to file # 69...
# File written, onto the next one....
# Pull Successful - Writing to file # 69...
# File written, onto the next one....
# Pull Successful - Writing to file # 70...
# File written, onto the next one....
# Pull Successful - Writing to file # 70...
# File written, onto the next one....
# Pull Successful - Writing to file # 70...
# File written, onto the next one....
# Pull Successful - Writing to file # 71...
# File written, onto the next one....
# Pull Successful - Writing to file # 71...
# File written, onto the next one....
# Pull Successful - Writing to file # 71...
# File written, onto the next one....
# Pull Successful - Writing to file # 72...
# File written, onto the next one....
# Pull Successful - Writing to file # 72...
# File written, onto the next one....
# Pull Successful - Writing to file # 72...
# File written, onto the next one....
# Pull Successful - Writing to file # 73...
# File written, onto the next one....
# Pull Successful - Writing to file # 73...
# File written, onto the next one....
# Pull Successful - Writing to file # 73...
# File written, onto the next one....
# Pull Successful - Writing to file # 74...
# File written, onto the next one....
# Pull Successful - Writing to file # 74...
# File written, onto the next one....
# Pull Successful - Writing to file # 74...
# File written, onto the next one....
# Pull Successful - Writing to file # 75...
# File written, onto the next one....
# Pull Successful - Writing to file # 75...
# File written, onto the next one....
# Pull Successful - Writing to file # 75...
# File written, onto the next one....
# Pull Successful - Writing to file # 76...
# File written, onto the next one....
# Pull Successful - Writing to file # 76...
# File written, onto the next one....
# Pull Successful - Writing to file # 76...
# File written, onto the next one....
# Pull Successful - Writing to file # 77...
# File written, onto the next one....
# Pull Successful - Writing to file # 77...
# File written, onto the next one....
# Pull Successful - Writing to file # 77...
# File written, onto the next one....
# Pull Successful - Writing to file # 78...
# File written, onto the next one....
# Pull Successful - Writing to file # 78...
# File written, onto the next one....
# Pull Successful - Writing to file # 78...
# File written, onto the next one....
# Pull Successful - Writing to file # 79...
# File written, onto the next one....
# Pull Successful - Writing to file # 79...
# File written, onto the next one....
# Pull Successful - Writing to file # 79...
# File written, onto the next one....
# Pull Successful - Writing to file # 80...
# File written, onto the next one....
# Pull Successful - Writing to file # 80...
# File written, onto the next one....
# Pull Successful - Writing to file # 80...
# File written, onto the next one....
# Pull Successful - Writing to file # 81...
# File written, onto the next one....
# Pull Successful - Writing to file # 81...
# File written, onto the next one....
# Pull Successful - Writing to file # 81...
# File written, onto the next one....
# Pull Successful - Writing to file # 82...
# File written, onto the next one....
# Pull Successful - Writing to file # 82...
# File written, onto the next one....
# Pull Successful - Writing to file # 82...
# File written, onto the next one....
# Pull Successful - Writing to file # 83...
# File written, onto the next one....
# Pull Successful - Writing to file # 83...
# File written, onto the next one....
# Pull Successful - Writing to file # 83...
# File written, onto the next one....
# Pull Successful - Writing to file # 84...
# File written, onto the next one....
# Pull Successful - Writing to file # 84...
# File written, onto the next one....
# Pull Successful - Writing to file # 84...
# File written, onto the next one....
# Pull Successful - Writing to file # 85...
# File written, onto the next one....
# Pull Successful - Writing to file # 85...
# File written, onto the next one....
# Pull Successful - Writing to file # 85...
# File written, onto the next one....
# Pull Successful - Writing to file # 86...
# File written, onto the next one....
# Pull Successful - Writing to file # 86...
# File written, onto the next one....
# Pull Successful - Writing to file # 86...
# File written, onto the next one....
# Pull Successful - Writing to file # 87...
# File written, onto the next one....
# Pull Successful - Writing to file # 87...
# File written, onto the next one....
# Pull Successful - Writing to file # 87...
# File written, onto the next one....
# Pull Successful - Writing to file # 88...
# File written, onto the next one....
# Pull Successful - Writing to file # 88...
# File written, onto the next one....
# Pull Successful - Writing to file # 88...
# File written, onto the next one....
# Pull Successful - Writing to file # 89...
# File written, onto the next one....
# Pull Successful - Writing to file # 89...
# File written, onto the next one....
# Pull Successful - Writing to file # 89...
# File written, onto the next one....
# Pull Successful - Writing to file # 90...
# File written, onto the next one....
# Pull Successful - Writing to file # 90...
# File written, onto the next one....
# Pull Successful - Writing to file # 90...
# File written, onto the next one....
# Pull Successful - Writing to file # 91...
# File written, onto the next one....
# Pull Successful - Writing to file # 91...
# File written, onto the next one....
# Pull Successful - Writing to file # 91...
# File written, onto the next one....

# %%
full_departures_df = pd.DataFrame()             # initializing empty dataframe to concatenate all the daily dataframes

for csv_file in glob.glob('./flight_data/Enterprise-II-Data/*.csv'):

    try:

        file: pd.DataFrame = pd.read_csv(csv_file)

        if not file.empty:

            full_departures_df = pd.concat([full_departures_df, file], ignore_index = True)
    
    except pd.errors.EmptyDataError:

        print(f"Skipping empty file {csv_file}")
# Out:
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-23_0.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-28_100.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-28_0.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-30_100.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-29_100.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-23_200.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-28_200.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-29_0.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-30_200.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-23_100.csv
# Skipping empty file ./flight_data/Enterprise-II-Data/YUL_Departures_2024-01-29_200.csv

# %%
full_departures_df.head(100)
# Out:
#    Flight Status Departure Airport Departure Gate Arrival IATA Code  \
# 0         landed               YUL            A63               DXB
# 1         landed               YUL            C82               EWR
# 2         landed               YUL            C83               EWR
# 3         landed               YUL            C84               EWR
# 4         active               YUL            C84               EWR
# ..           ...               ...            ...               ...
# 95      diverted               YUL            NaN               BOS
# 96        landed               YUL            C86               BOS
# 97     scheduled               YUL            C75               BOS
# 98        landed               YUL            A50               BRU
# 99        active               YUL            A67               CCC
#
#           Scheduled Departure           Actual Departure  Delay (in Minutes)  \
# 0   2024-04-08T10:20:00+00:00  2024-04-08T10:28:00+00:00                 8.0
# 1   2024-04-08T08:15:00+00:00  2024-04-08T08:43:00+00:00                28.0
# 2   2024-04-08T13:10:00+00:00  2024-04-08T13:20:00+00:00                10.0
# 3   2024-04-08T15:10:00+00:00  2024-04-08T15:32:00+00:00                22.0
# 4   2024-04-08T20:00:00+00:00                        NaN               122.0
# ..                        ...                        ...                 ...
# 95  2024-03-11T07:00:00+00:00  2024-03-11T06:53:00+00:00                 NaN
# 96  2024-03-11T08:15:00+00:00  2024-03-11T09:21:00+00:00                66.0
# 97  2024-03-11T16:45:00+00:00  2024-03-11T18:32:00+00:00               108.0
# 98  2024-03-11T19:50:00+00:00  2024-03-11T20:09:00+00:00                19.0
# 99  2024-03-11T17:00:00+00:00  2024-03-11T17:26:00+00:00                27.0
#
#    Airline Name Flight Number
# 0      Emirates         EK244
# 1    Air Canada        AC8938
# 2    Air Canada        AC8940
# 3    Air Canada        AC8942
# 4    Air Canada        AC8946
# ..          ...           ...
# 95    Airsprint           NaN
# 96   Air Canada         AC748
# 97   Air Canada         AC752
# 98   Air Canada         AC832
# 99  Air Transat         TS856
#
# [100 rows x 9 columns]

# %%
full_departures_df.to_csv('./flight_data/Enterprise-II-Data/concatenated_data/Full_Departures_Data.csv', index = False)
